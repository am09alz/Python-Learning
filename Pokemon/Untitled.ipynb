# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\guest-pc\Desktop\Data Science\Python\Pokemon\Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df[['Name','Type 1']][0:5])
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %%
print(df.iloc[:,1])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
for index, row in df.iterrows():
    print(row['Name'])
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %%
df.loc[df['Name']=='Kakuna']
# Out:
#      #    Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 17  14  Kakuna    Bug  Poison  45      25       50       25       25     35
#
#     Generation  Legendary
# 17           1      False

# %%
df.sort_values(['Type 1','Type 2'],ascending=[1,0])
# Out:
#        #                 Name Type 1 Type 2  Legendary  Total   HP  Attack  \
# 307  283              Surskit    Bug  Water      False    269   40      30
# 220  205           Forretress    Bug  Steel      False    465   75      90
# 228  212               Scizor    Bug  Steel      False    500   70     130
# 229  212    ScizorMega Scizor    Bug  Steel      False    600   70     150
# 460  413  WormadamTrash Cloak    Bug  Steel      False    424   60      69
# ..   ...                  ...    ...    ...        ...    ...  ...     ...
# 655  594            Alomomola  Water    NaN      False    470  165      75
# 724  656              Froakie  Water    NaN      False    314   41      56
# 725  657            Frogadier  Water    NaN      False    405   54      63
# 762  692            Clauncher  Water    NaN      False    330   50      53
# 763  693            Clawitzer  Water    NaN      False    500   71      73
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df = df.drop(columns=['Total'])

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)

# %%
cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN      False    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
new_data = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['HP']<50)]
new_data
# Out:
#        #       Name Type 1  Type 2  Legendary  Total  HP  Attack  Defense  \
# 0      1  Bulbasaur  Grass  Poison      False    318  45      49       49
# 48    43     Oddish  Grass  Poison      False    320  45      50       55
# 451  406      Budew  Grass  Poison      False    280  40      30       35
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 0         65       65     45           1
# 48        75       65     30           1
# 451       50       70     55           4

# %%
new_data = new_data.reset_index(drop = True)
new_data
# Out:
#    index    #       Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0      0    1  Bulbasaur  Grass  Poison      False    318  45      49
# 1     48   43     Oddish  Grass  Poison      False    320  45      50
# 2    451  406      Budew  Grass  Poison      False    280  40      30
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       55       75       65     30           1
# 2       35       50       70     55           4

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Legendary  Total  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      False    625
# 7      6  CharizardMega Charizard X      Fire    Dragon      False    634
# 8      6  CharizardMega Charizard Y      Fire    Flying      False    634
# 12     9    BlastoiseMega Blastoise     Water       NaN      False    630
# 19    15      BeedrillMega Beedrill       Bug    Poison      False    495
# 23    18        PidgeotMega Pidgeot    Normal    Flying      False    579
# 71    65      AlakazamMega Alakazam   Psychic       NaN      False    590
# 87    80        SlowbroMega Slowbro     Water   Psychic      False    590
# 102   94          GengarMega Gengar     Ghost    Poison      False    600
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      False    590
# 137  127          PinsirMega Pinsir       Bug    Flying      False    600
# 141  130      GyaradosMega Gyarados     Water      Dark      False    640
# ...

# %%
df.loc[df['Type 1'].str.contains('Normal|Rock')]
# Out:
#        #                 Name  Type 1  Type 2  Legendary  Total   HP  Attack  \
# 20    16               Pidgey  Normal  Flying      False    251   40      45
# 21    17            Pidgeotto  Normal  Flying      False    349   63      60
# 22    18              Pidgeot  Normal  Flying      False    479   83      80
# 23    18  PidgeotMega Pidgeot  Normal  Flying      False    579   83      80
# 24    19              Rattata  Normal     NaN      False    253   30      56
# ..   ...                  ...     ...     ...        ...    ...  ...     ...
# 768  698               Amaura    Rock     Ice      False    362   77      59
# 769  699              Aurorus    Rock     Ice      False    521  123      77
# 773  703              Carbink    Rock   Fairy      False    500   50      50
# 795  719              Diancie    Rock   Fairy       True    600   50     100
# 796  719  DiancieMega Diancie    Rock   Fairy       True    700   50     160
#
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('Normal|rock',regex=True,flags=re.I)]
# Out:
#        #                 Name  Type 1  Type 2  Legendary  Total   HP  Attack  \
# 20    16               Pidgey  Normal  Flying      False    251   40      45
# 21    17            Pidgeotto  Normal  Flying      False    349   63      60
# 22    18              Pidgeot  Normal  Flying      False    479   83      80
# 23    18  PidgeotMega Pidgeot  Normal  Flying      False    579   83      80
# 24    19              Rattata  Normal     NaN      False    253   30      56
# ..   ...                  ...     ...     ...        ...    ...  ...     ...
# 768  698               Amaura    Rock     Ice      False    362   77      59
# 769  699              Aurorus    Rock     Ice      False    521  123      77
# 773  703              Carbink    Rock   Fairy      False    500   50      50
# 795  719              Diancie    Rock   Fairy       True    600   50     100
# 796  719  DiancieMega Diancie    Rock   Fairy       True    700   50     160
#
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Normal|Rock', regex=True,flags=re.I)]

# %%
df.loc[df['Name'].str.contains('^pi[a-z]', regex=True, flags=re.I)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Total   HP  \
# 20    16               Pidgey    Normal    Flying      False    251   40
# 21    17            Pidgeotto    Normal    Flying      False    349   63
# 22    18              Pidgeot    Normal    Flying      False    479   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False    579   83
# 30    25              Pikachu  Electric       NaN      False    320   35
# 136  127               Pinsir       Bug       NaN      False    500   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False    600   65
# 186  172                Pichu  Electric       NaN      False    205   20
# 219  204               Pineco       Bug       NaN      False    290   50
# 239  221            Piloswine       Ice    Ground      False    450  100
# 438  393               Piplup     Water       NaN      False    314   53
# 558  499              Pignite      Fire  Fighting      False    418   90
# ...

# %%
L=(['a','b'])
# Out:
# ['a', 'b']

# %%
L.append((['a','b']))

# %%
L
# Out:
# ['a', 'b', ['a', 'b'], ['a', 'b']]

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(["8", 6, "7.5", 3, "0.9",'test'])

# %%
pd.to_numeric(s,errors='coerce')
# Out:
# 0    8.0
# 1    6.0
# 2    7.5
# 3    3.0
# 4    0.9
# 5    NaN
# dtype: float64

# %%
s.astype('float')
# Out:
# 0    8.0
# 1    6.0
# 2    7.5
# 3    3.0
# 4    0.9
# dtype: float64
